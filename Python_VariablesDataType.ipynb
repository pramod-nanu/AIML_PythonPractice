# %% [markdown]
# <a href="https://colab.research.google.com/github/pramod-nanu/AIML_PythonPractice/blob/main/Python_VariablesDataType.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World I am Data Scientist")
# Out:
# Hello World I am Data Scientist

# %%
x=150
x
x+150

# We declared x as variable
# Out:
# 300

# %%
_cash = 150

# %%
# Data Type
a = 30
b = "Hello"
print(type(a))
id(a)
c = 9.23
print(type(c))
b = int(c)
print(type(b))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
a = 1
b = 1
print(id(a))
print(id(b))
True + True
# Out:
# 11654376
# 11654376

# %%
# Boolean Data types True is 1 and False is 0
print(True + True)
True - False
a = True
print(type(a))
# Out:
# 2
# <class 'bool'>

# %%
# String
paragraph = """This is Pramod
I am going to Mumbai tomorrow"""
print(paragraph)
# Out:
# This is Pramod
# I am going to Mumbai tomorrow

# %%
str = 'I am good'
str
# Out:
# 'I am good'

# %%
s1 = 'Artificial Intelligence'
print(s1[-5])
print(s1[2])
print(s1.index('A'))
print(s1[0:5])
print(s1[:5])
print(s1[:-5])
print(s1[:])
print(len(s1))
# Out:
# g
# t
# 0
# Artif
# Artif
# Artificial Intelli
# Artificial Intelligence
# 23
